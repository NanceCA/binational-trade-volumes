# %% [markdown]
# ## Understanding Trade Volumes Between Mexico and the United States

# %%
#run import cells when launching the notebook for the first time
import pandas as pd

# %%
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ## General Imports from Mexico to the United States

# %%
# starting exploratory data analysis to understand general trends over time

# %%
imports = pd.read_csv('./data/usitc/general-imports.csv')

# %%
imports.head()
# Out:
#   Data Type - General Imports  Total    Year 1997    Year 1998     Year 1999  \
# 0       General Customs Value    NaN  85872344740  94708666043  109706486039
#
#       Year 2000     Year 2001     Year 2002     Year 2003     Year 2004  \
# 0  135910533679  131432956779  134732185087  138073296952  155845665796
#
#               ...                 Year 2010     Year 2011     Year 2012  \
# 0             ...              229985623006  262873595958  277593639546
#
#       Year 2013     Year 2014     Year 2015     Year 2016     Year 2017  \
# 0  280556040242  295729962846  296433325024  293500606660  312808758044
#
#       Year 2018  Percent Change 2017 - 2018
# 0  346100585788                        10.6
#
# [1 rows x 25 columns]

# %%
imports.shape
# Out:
# (1, 25)

# %%
imports.describe()
# Out:
#        Total     Year 1997     Year 1998     Year 1999     Year 2000  \
# count    0.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# mean     NaN  8.587234e+10  9.470867e+10  1.097065e+11  1.359105e+11
# std      NaN           NaN           NaN           NaN           NaN
# min      NaN  8.587234e+10  9.470867e+10  1.097065e+11  1.359105e+11
# 25%      NaN  8.587234e+10  9.470867e+10  1.097065e+11  1.359105e+11
# 50%      NaN  8.587234e+10  9.470867e+10  1.097065e+11  1.359105e+11
# 75%      NaN  8.587234e+10  9.470867e+10  1.097065e+11  1.359105e+11
# max      NaN  8.587234e+10  9.470867e+10  1.097065e+11  1.359105e+11
#
#           Year 2001     Year 2002     Year 2003     Year 2004     Year 2005  \
# count  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# mean   1.314330e+11  1.347322e+11  1.380733e+11  1.558457e+11  1.701979e+11
# std             NaN           NaN           NaN           NaN           NaN
# ...

# %%
imports.plot(kind='bar')

# %% [markdown]
# **Insight is that general imports from Mexico to the United States have been increasing overt time**
#
# Next steps include
# 1. Transpose the dataset in order to determine the drop in years
# 1. Understand if imports according to commodities has changed over time

# %% [markdown]
# ## Imports for Consumption from Mexico to the United States

# %%
# starting exploratory data analysis to understand general trends over time

# %%
importsConsumption = pd.read_csv('./data/usitc/imports-for-consumption.csv')

# %%
importsConsumption.describe()
# Out:
#        Total     Year 1997     Year 1998     Year 1999     Year 2000  \
# count    0.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# mean     NaN  8.500479e+10  9.301736e+10  1.090182e+11  1.347344e+11
# std      NaN           NaN           NaN           NaN           NaN
# min      NaN  8.500479e+10  9.301736e+10  1.090182e+11  1.347344e+11
# 25%      NaN  8.500479e+10  9.301736e+10  1.090182e+11  1.347344e+11
# 50%      NaN  8.500479e+10  9.301736e+10  1.090182e+11  1.347344e+11
# 75%      NaN  8.500479e+10  9.301736e+10  1.090182e+11  1.347344e+11
# max      NaN  8.500479e+10  9.301736e+10  1.090182e+11  1.347344e+11
#
#           Year 2001     Year 2002     Year 2003     Year 2004     Year 2005  \
# count  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# mean   1.305089e+11  1.341212e+11  1.371993e+11  1.549588e+11  1.692161e+11
# std             NaN           NaN           NaN           NaN           NaN
# ...

# %%
importsConsumption.plot(kind='bar')

# %% [markdown]
# ## Understanding Mexico Trade Volumes with all other International Partners for Comparative Analysis(Aggregate)

# %%
wto = pd.read_csv('./data/wto/WtoData_20200116074154.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 37: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-eb95808812d2> in <module>
# ----> 1 wto = pd.read_csv('./data/wto/WtoData_20200116074154.csv')
#
# ...
